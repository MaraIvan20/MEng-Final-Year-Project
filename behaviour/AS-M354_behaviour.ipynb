# %%
import sys
import os
sys.path.append(os.path.abspath("C:/Users/MARA/Desktop/IMPERIAL YEAR 4/Final year project/code"))

 
import numpy as np
import matplotlib.pyplot as plt


import CURBD.curbd as curbd
import PyalData.pyaldata as pyaldata

# %%
data_dir = "C:/Users/MARA/Desktop/IMPERIAL YEAR 4/Final year project/code/datasets/autism data/AS-M354/AS-M354-pyaldata2"  # place here absolute path towards folder with session files for the AS-M354 model in pyaldata format
files = os.listdir(data_dir)

# %% [markdown]
# Code to look at the hand velocity mean and std:
# 1. within session (between trials)
# 2. within animal model (between sessions)
# (note: here we focus on successful trials only)

# %% [markdown]
# Look at mean and variability within one session:

# %%
# Code to look at the mean and std of velocity within one session:

fpath = os.path.join(data_dir, "AS-M354_session4.mat")  # change to the session you want
# load TrialData .mat file into a DataFrame
df1 = pyaldata.mat2dataframe(fpath, shift_idx_fields=True)

df1 = pyaldata.select_trials(df1, "success == 1")

df1 = pyaldata.restrict_to_interval(df1, "idx_mo", end_point_name=None, rel_start=-50, rel_end=700)

avg_vel1 = np.mean(df1.vel)

std_vel1 = np.std([trial_vel for trial_vel in df1.vel], axis = 0)

plt.plot(range(0, len(avg_vel1)*2, 2), avg_vel1, color='b')

plt.fill_between(range(0, len(avg_vel1)*2, 2), avg_vel1-std_vel1/2, avg_vel1+std_vel1/2, alpha=0.3, color='b')

plt.axvline(x=100, linestyle='--', color='r')

plt.legend(("mean (trial-averaged)",'std','movement onset'), fontsize=8)
plt.xlabel("Time(milliseconds)", fontsize=8)
plt.ylabel("Velocity magnitude", fontsize=8)
plt.xticks(fontsize=8)
plt.yticks(fontsize=8)
# Out:
# (array([0.  , 0.05, 0.1 , 0.15, 0.2 , 0.25, 0.3 , 0.35]),
#  [Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, '')])

# %%
# Code to look at the mean and std of velocity within one session:
avg_ga1 = np.mean(df1.ga)

std_ga1 = np.std([trial_ga for trial_ga in df1.ga], axis = 0)

plt.plot(range(0, len(avg_ga1)*2, 2), avg_ga1, color='b')

plt.fill_between(range(0, len(avg_ga1)*2, 2), avg_ga1-std_ga1/2, avg_ga1+std_ga1/2, alpha=0.3, color='b')

plt.axvline(x=100, linestyle='--', color='r')

plt.legend(("mean (trial-averaged)",'std','movement onset'), fontsize=8)
plt.xlabel("Time(milliseconds)", fontsize=8)
plt.ylabel("Velocity magnitude", fontsize=8)
plt.xticks(fontsize=8)
plt.yticks(fontsize=8)
# Out:
# (array([1.6, 1.8, 2. , 2.2, 2.4, 2.6, 2.8, 3. , 3.2, 3.4]),
#  [Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, '')])

# %%
# Code to look at the mean and std of velocity within one session:
avg_da1 = np.mean(df1.da)

std_da1 = np.std([trial_da for trial_da in df1.da], axis = 0)

plt.plot(range(0, len(avg_da1)*2, 2), avg_da1, color='b')

plt.fill_between(range(0, len(avg_da1)*2, 2), avg_da1-std_da1/2, avg_da1+std_da1/2, alpha=0.3, color='b')

plt.axvline(x=100, linestyle='--', color='r')

plt.legend(("mean (trial-averaged)",'std','movement onset'), fontsize=8)
plt.xlabel("Time(milliseconds)", fontsize=8)
plt.ylabel("Velocity magnitude", fontsize=8)
plt.xticks(fontsize=8)
plt.yticks(fontsize=8)
# Out:
# (array([-20., -15., -10.,  -5.,   0.,   5.,  10.,  15.,  20.,  25.,  30.]),
#  [Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, '')])

# %%
avg_xhand = np.mean([trial_hand[:,0] for trial_hand in df1.hand], axis=0)
avg_yhand = np.mean([trial_hand[:,1] for trial_hand in df1.hand], axis=0)
avg_zhand = np.mean([trial_hand[:,2] for trial_hand in df1.hand], axis=0)


std_xhand = np.std([trial_hand[:,0] for trial_hand in df1.hand], axis=0)
std_yhand = np.std([trial_hand[:,1] for trial_hand in df1.hand], axis=0)
std_zhand = np.std([trial_hand[:,2] for trial_hand in df1.hand], axis=0)

# %%
plt.plot(range(0, len(avg_xhand)*2, 2), avg_xhand, color='b')

plt.fill_between(range(0, len(avg_xhand)*2, 2), avg_xhand-std_xhand/2, avg_xhand+std_xhand/2, alpha=0.3, color='b')

plt.axvline(x=100, linestyle='--', color='r')

plt.legend(("mean (trial-averaged)",'std','movement onset'), fontsize=8)
plt.xlabel("Time(milliseconds)", fontsize=8)
plt.ylabel("Velocity magnitude", fontsize=8)
plt.xticks(fontsize=8)
plt.yticks(fontsize=8)
# Out:
# (array([-18., -16., -14., -12., -10.,  -8.,  -6.,  -4.,  -2.,   0.]),
#  [Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, '')])

# %%
plt.plot(range(0, len(avg_yhand)*2, 2), avg_yhand, color='b')

plt.fill_between(range(0, len(avg_yhand)*2, 2), avg_yhand-std_yhand/2, avg_yhand+std_yhand/2, alpha=0.3, color='b')

plt.axvline(x=100, linestyle='--', color='r')

plt.legend(("mean (trial-averaged)",'std','movement onset'), fontsize=8)
plt.xlabel("Time(milliseconds)", fontsize=8)
plt.ylabel("Velocity magnitude", fontsize=8)
plt.xticks(fontsize=8)
plt.yticks(fontsize=8)
# Out:
# (array([-14., -12., -10.,  -8.,  -6.,  -4.,  -2.,   0.,   2.]),
#  [Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, '')])

# %%
plt.plot(range(0, len(avg_zhand)*2, 2), avg_zhand, color='b')

plt.fill_between(range(0, len(avg_zhand)*2, 2), avg_zhand-std_zhand/2, avg_zhand+std_zhand/2, alpha=0.3, color='b')

plt.axvline(x=100, linestyle='--', color='r')

plt.legend(("mean (trial-averaged)",'std','movement onset'), fontsize=8)
plt.xlabel("Time(milliseconds)", fontsize=8)
plt.ylabel("Velocity magnitude", fontsize=8)
plt.xticks(fontsize=8)
plt.yticks(fontsize=8)
# Out:
# (array([-4., -2.,  0.,  2.,  4.,  6.,  8.]),
#  [Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, '')])

# %%
fig = plt.figure(figsize = (5,5))
ax = plt.axes(projection='3d')
ax.grid()


ax.plot(avg_xhand, avg_yhand, avg_zhand)


ax.set_title('3D Scatter Plot')

# Set axes label
ax.set_xlabel('x', labelpad=20)
ax.set_ylabel('y', labelpad=20)
ax.set_zlabel('z', labelpad=20)
# Out:
# Text(0.5, 0, 'z')

# %%
fig = plt.figure(figsize = (5,5))
ax = plt.axes(projection='3d')
ax.grid()

for i in range(5):
    ax.plot(df1.hand[i][:,0], df1.hand[i][:,1], df1.hand[i][:,2])

ax.set_title('3D Scatter Plot')

# Set axes label
ax.set_xlabel('x', labelpad=20)
ax.set_ylabel('y', labelpad=20)
ax.set_zlabel('z', labelpad=20)
# Out:
# Text(0.5, 0, 'z')

# %% [markdown]
# Look at the mean and variability between sessions within one animal model:

# %%
success_rate_list = []
avg_vel_list = []
avg_ga_list = []
avg_da_list = []
avg_xhand_list = []
avg_yhand_list = []
avg_zhand_list = []

for file_name in files:
    # Code to look at the mean and std of velocity within one session:

    fpath = os.path.join(data_dir, file_name)  # change to the session you want
    # load TrialData .mat file into a DataFrame
    df = pyaldata.mat2dataframe(fpath, shift_idx_fields=True)

    total_no_trials = len(df)

    df = pyaldata.select_trials(df, "success == 1")

    no_successful_trials = len(df)

    success_rate = no_successful_trials/total_no_trials

    success_rate_list.append(success_rate)

    if len(df) != 0:  # only consider sessions with successful trials

        df = pyaldata.restrict_to_interval(df, "idx_mo", end_point_name=None, rel_start=-50, rel_end=700)

        avg_vel = np.mean(df.vel)
        avg_vel_list.append(avg_vel)

        avg_ga = np.mean(df.ga)
        avg_ga_list.append(avg_ga)

        avg_da = np.mean(df.da)
        avg_da_list.append(avg_da)

        avg_xhand = np.mean([trial_hand[:,0] for trial_hand in df.hand], axis=0)
        avg_xhand_list.append(avg_xhand)

        avg_yhand = np.mean([trial_hand[:,1] for trial_hand in df.hand], axis=0)
        avg_yhand_list.append(avg_yhand)

        avg_zhand = np.mean([trial_hand[:,2] for trial_hand in df.hand], axis=0)
        avg_zhand_list.append(avg_zhand)



model_avg_vel = np.mean(avg_vel_list, axis=0)
model_std_vel = np.std(avg_vel_list, axis=0)

model_avg_ga = np.mean(avg_ga_list, axis=0)
model_std_ga = np.std(avg_ga_list, axis=0)

model_avg_da = np.mean(avg_da_list, axis=0)
model_std_da = np.std(avg_da_list, axis=0)

model_avg_xhand = np.mean(avg_xhand_list, axis=0)
model_std_xhand = np.std(avg_xhand_list, axis=0)

model_avg_yhand = np.mean(avg_yhand_list, axis=0)
model_std_yhand = np.std(avg_yhand_list, axis=0)

model_avg_zhand = np.mean(avg_zhand_list, axis=0)
model_std_zhand = np.std(avg_zhand_list, axis=0)

# %%
success_rate_list
# Out:
# [0.6206896551724138,
#  0.6730769230769231,
#  0.0,
#  0.5084745762711864,
#  0.6,
#  0.6,
#  0.5416666666666666,
#  0.21428571428571427]

# %%
plt.figure()
plt.plot(range(0, len(model_avg_vel)*2, 2), model_avg_vel, color='b')
plt.fill_between(range(0, len(model_std_vel)*2, 2), model_avg_vel-model_std_vel/2, model_avg_vel+model_std_vel/2, alpha=0.3, color='b')
plt.axvline(x=100, linestyle='--', color='r')
plt.legend(("mean",'std','movement onset'), fontsize=8)
plt.xlabel("Time(milliseconds)", fontsize=8)
plt.ylabel("Velocity magnitude (m/s)", fontsize=8)
plt.xticks(fontsize=8)
plt.yticks(fontsize=8)
plt.title("Hand velocity magnitude across sessions for AS-M354", pad=10, fontsize=10)


plt.figure()
plt.plot(range(0, len(model_avg_ga)*2, 2), model_avg_ga, color='b')
plt.fill_between(range(0, len(model_std_ga)*2, 2), model_avg_ga-model_std_ga/2, model_avg_ga+model_std_ga/2, alpha=0.3, color='b')
plt.axvline(x=100, linestyle='--', color='r')
plt.legend(("mean",'std','movement onset'), fontsize=8)
plt.xlabel("Time(milliseconds)", fontsize=8)
plt.ylabel("Grip aperture", fontsize=8)
plt.xticks(fontsize=8)
plt.yticks(fontsize=8)
plt.title("Grip aperture across sessions for AS-M354", pad=10, fontsize=10)


plt.figure()
plt.plot(range(0, len(model_avg_da)*2, 2), model_avg_da, color='b')
plt.fill_between(range(0, len(model_std_da)*2, 2), model_avg_da-model_std_da/2, model_avg_da+model_std_da/2, alpha=0.3, color='b')
plt.axvline(x=100, linestyle='--', color='r')
plt.legend(("mean",'std','movement onset'), fontsize=8)
plt.xlabel("Time(milliseconds)", fontsize=8)
plt.ylabel("Digit angle", fontsize=8)
plt.xticks(fontsize=8)
plt.yticks(fontsize=8)
plt.title("Digit angle across sessions for AS-M354", pad=10, fontsize=10)


plt.figure()
plt.plot(range(0, len(model_avg_xhand)*2, 2), model_avg_xhand, color='b')
plt.fill_between(range(0, len(model_std_xhand)*2, 2), model_avg_xhand-model_std_xhand/2, model_avg_xhand+model_std_xhand/2, alpha=0.3, color='b')
plt.axvline(x=100, linestyle='--', color='r')
plt.legend(("mean",'std','movement onset'), fontsize=8)
plt.xlabel("Time(milliseconds)", fontsize=8)
plt.ylabel("x-position (cm)", fontsize=8)
plt.xticks(fontsize=8)
plt.yticks(fontsize=8)
plt.title("x-component of hand trajectory across sessions for AS-M354", pad=10, fontsize=10)


plt.figure()
plt.plot(range(0, len(model_avg_yhand)*2, 2), model_avg_yhand, color='b')
plt.fill_between(range(0, len(model_std_yhand)*2, 2), model_avg_yhand-model_std_yhand/2, model_avg_yhand+model_std_yhand/2, alpha=0.3, color='b')
plt.axvline(x=100, linestyle='--', color='r')
plt.legend(("mean",'std','movement onset'), fontsize=8)
plt.xlabel("Time(milliseconds)", fontsize=8)
plt.ylabel("y-position (cm)", fontsize=8)
plt.xticks(fontsize=8)
plt.yticks(fontsize=8)
plt.title("y-component of hand trajectory across sessions for AS-M354", pad=10, fontsize=10)


plt.figure()
plt.plot(range(0, len(model_avg_zhand)*2, 2), model_avg_zhand, color='b')
plt.fill_between(range(0, len(model_std_zhand)*2, 2), model_avg_zhand-model_std_zhand/2, model_avg_zhand+model_std_zhand/2, alpha=0.3, color='b')
plt.axvline(x=100, linestyle='--', color='r')
plt.legend(("mean",'std','movement onset'), fontsize=8)
plt.xlabel("Time(milliseconds)", fontsize=8)
plt.ylabel("z-position (cm)", fontsize=8)
plt.xticks(fontsize=8)
plt.yticks(fontsize=8)
plt.title("z-component of hand trajectory across sessions for AS-M354", pad=10, fontsize=10)

# plot for xhand, yhand, zhand separately, then 3d trajectory for model if std are low enough for this trajectory to be relevant-- can you include std in 3d?
# Out:
# Text(0.5, 1.0, 'z-component of hand trajectory across sessions for AS-M354')

# %%
np.mean(model_std_vel)
# Out:
# 0.014086833493573326

# %%
fig = plt.figure(figsize = (5,5))
ax = plt.axes(projection='3d')
ax.grid()


ax.plot(model_avg_xhand, model_avg_yhand, model_avg_zhand)


ax.set_title('3D session-averaged hand trajectory')

# Set axes label
ax.set_xlabel('x', labelpad=20)
ax.set_ylabel('y', labelpad=20)
ax.set_zlabel('z', labelpad=20)
# Out:
# Text(0.5, 0, 'z')
